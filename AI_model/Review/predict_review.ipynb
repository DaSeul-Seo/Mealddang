# %%
import re
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.python.client import device_lib
from tensorflow.keras.models import load_model
from eunjeon import Mecab
import numpy as np
import pickle
# Out:
# WARNING:tensorflow:From c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# 토크나이저 로드 함수
def load_tokenizer(filepath):
    with open(filepath, 'rb') as f:
        tokenizer = pickle.load(f)
    return tokenizer

# %%
from konlpy.tag import Mecab

# %%
data = pd.read_csv('./data/tokenized_data.csv', encoding_errors='ignore', low_memory=False)
data['new_label']=None
data['tokenized_comment']=None
loaded_model = load_model('./model/final_model_v0.h5')
tokenizer = Tokenizer()
mecab = Mecab('C:/mecab/mecab-ko-dic')
# Out:
# WARNING:tensorflow:From c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
# 예측 과정에서의 토크나이저 로드
tokenizer = load_tokenizer('./model/tokenizer.pkl')
stopwords = load_tokenizer('./model/stopwords.pkl')

# %%
def sentiment_predict(new_sentence):
    new_sentence = mecab.morphs(new_sentence)
    new_sentence = [word for word in new_sentence if word not in stopwords]
    
    if not new_sentence:
        print("토큰이 없어 중립 리뷰입니다.")
        return -1
    
    # 시퀀스 길이 설정
    max_len = 80
    
    # 시퀀스를 인코딩하고 패딩
    encoded = tokenizer.texts_to_sequences([new_sentence])
    pad_new = pad_sequences(encoded, maxlen=max_len)
    
    # 모델에 입력하고 예측 수행
    score = loaded_model.predict(pad_new)[0]
    
    score = float(score)  # 배열에서 스칼라 값으로 변환
    
    if score > 0.5:
        print("{:.2f}% 확률로 긍정 리뷰입니다.".format(score * 100))
        return 1
    else:
        print("{:.2f}% 확률로 부정 리뷰입니다.".format((1 - score) * 100))
        return 0

# %%
data['tokenized_comments'] = None

# %%
for index, row in data.iterrows():
    sp = sentiment_predict(row['Review'])
    if sp == 1:
        data.at[index, 'new_label'] = '1'
    elif sp == -1:
        data.at[index, 'new_label'] = '-1'
    else:
        data.at[index, 'new_label'] = '0'

    # mecab.pos 함수를 호출하기 전에 body가 str 타입인지 확인
    if isinstance(row['Review'], str):
        tokenized_comments = []
        pos_tags = mecab.pos(row['Review'])
        for token, pos in pos_tags:
            # 형태소가 동사(VV) 또는 형용사(VA)인 경우에만 tokenized_comments에 추가
            if pos in ['Noun', 'Adjective']:
                tokenized_comments.append(token)
        data.at[index, 'tokenized_comments'] = tokenized_comments
# Out:
# 1/1 [==============================] - 1s 628ms/step
# 99.98% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 62.44% 확률로 긍정 리뷰입니다.
# C:\Users\USER\AppData\Local\Temp\ipykernel_13632\2931568357.py:19: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   score = float(score)  # 배열에서 스칼라 값으로 변환
# 1/1 [==============================] - 0s 54ms/step
# 99.09% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 92.45% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 52ms/step
# 82.66% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 53ms/step
# 99.24% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 45ms/step
# 89.87% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 98.43% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 32ms/step
# 93.54% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 96.85% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 74.78% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 93ms/step
# 94.25% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 99.44% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 99.51% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 82.93% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 99.61% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 99.89% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 81.94% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 81.03% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 46ms/step
# 80.75% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 75.09% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 33ms/step
# 82.97% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 50ms/step
# 99.50% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 97.62% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 94.18% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 95.41% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 54.98% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 50ms/step
# 98.30% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 55ms/step
# 88.38% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 96.96% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 97.66% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 47ms/step
# 95.51% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 99.81% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 97.14% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 52ms/step
# 96.51% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 85.01% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 87.70% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 60ms/step
# 73.46% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 49ms/step
# 97.85% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 72.97% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 90.20% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 99.44% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 94.39% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 92.13% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 92.45% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 97.08% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 99.01% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 94.19% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 50ms/step
# 60.73% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 51ms/step
# 72.16% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 50ms/step
# 98.84% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 45ms/step
# 92.45% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 97.53% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 53ms/step
# 84.17% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 86.98% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 89.46% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 99.38% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 97.02% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 47ms/step
# 92.69% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 98.17% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 79.56% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 95.82% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 99.28% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 45ms/step
# 57.46% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 97.09% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 53ms/step
# 89.73% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 89.42% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 99.76% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 96.28% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 50ms/step
# 77.08% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 50ms/step
# 87.46% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 76.78% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 87.83% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 99.62% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 33ms/step
# 92.43% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 99.53% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 79.68% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 96.28% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 85.70% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 46ms/step
# 70.04% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 97.87% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 98.20% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 98.47% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 97.31% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 97.34% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 98.30% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 95.88% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 88.46% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 98.30% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 97.37% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 170ms/step
# 94.74% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 53ms/step
# 98.38% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 47ms/step
# 99.21% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 52ms/step
# 98.30% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 57ms/step
# 95.54% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 52ms/step
# 51.93% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 58ms/step
# 99.03% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 50ms/step
# 93.11% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 46ms/step
# 86.27% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 99.70% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 95.79% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 93.39% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 97.88% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 99.02% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 99.79% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 62.36% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 61.20% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 85.96% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 97.34% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 98.45% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 98.38% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 87.52% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 50ms/step
# 87.11% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 89.45% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 92.45% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 31ms/step
# 93.54% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 92.45% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 63ms/step
# 99.49% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 96.91% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 92.85% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 99.54% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 93.72% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 92.94% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 95.46% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 99.69% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 82.80% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 92.93% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 96.16% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 33ms/step
# 90.57% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 99.80% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 99.71% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 96.21% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 89.04% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 98.30% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 95.89% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 70.04% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 96.40% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 96.95% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 95.89% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 97.92% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 70.91% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 99.59% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 61ms/step
# 98.35% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 97.49% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 99.68% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 46ms/step
# 94.25% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 45ms/step
# 94.51% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 99.14% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 87.11% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 98.11% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 99.13% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 98.91% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 32ms/step
# 97.57% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 32ms/step
# 66.14% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 33ms/step
# 97.73% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 80.52% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 99.23% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 45ms/step
# 86.10% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 97.77% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 97.58% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 99.25% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 33ms/step
# 99.52% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 32ms/step
# 99.39% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 99.68% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 83ms/step
# 97.18% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 98.31% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 87.11% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 33ms/step
# 98.40% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 33ms/step
# 99.97% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 98.30% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 99.90% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 99.64% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 99.26% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 95.81% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 98.56% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 98.20% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 87.11% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 84.63% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 52ms/step
# 96.57% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 30ms/step
# 97.82% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 99.43% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 97.72% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 97.19% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 99.96% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 96.58% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 95.19% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 59ms/step
# 96.31% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 99.43% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 32ms/step
# 97.37% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 54.00% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 82.63% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 94.54% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 98.63% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 99.66% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 93.43% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 93.36% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 92.07% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 93.54% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 94.93% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 88.66% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 98.30% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 78.27% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 79.56% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 79.56% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 99.52% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 33ms/step
# 69.79% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 64.45% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 95.68% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 53.82% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 97.51% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 52ms/step
# 94.80% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 62.81% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 81.97% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 33ms/step
# 85.26% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 99.44% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 99.03% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 46ms/step
# 96.72% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 59.71% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 99.30% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 90.73% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 96.85% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 95.47% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 53.21% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 52ms/step
# 74.82% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 29ms/step
# 99.68% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 99.40% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 45ms/step
# 57.90% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 95.78% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 47ms/step
# 99.76% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 52.11% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 96.70% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 50ms/step
# 98.30% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 55.80% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 95.14% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 94.82% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 96.85% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 97.28% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 99.37% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 98.01% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 84.69% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 97.96% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 99.32% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 91.20% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 98.02% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 97.95% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 98.51% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 98.22% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 96.83% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 46ms/step
# 99.09% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 99.48% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 98.92% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 99.80% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 72ms/step
# 95.60% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 49ms/step
# 59.32% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 78.14% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 99.02% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 33ms/step
# 89.02% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 99.35% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 97.31% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 32ms/step
# 94.67% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 99.25% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 98.30% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 33ms/step
# 99.52% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 80.38% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 33ms/step
# 79.02% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 99.69% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 98.43% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 95.97% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 80.07% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 97.09% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 33ms/step
# 79.65% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 98.79% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 87.56% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 66ms/step
# 93.22% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 33ms/step
# 95.82% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 98.13% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 68.04% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 70.00% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 98.62% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 98.11% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 98.67% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 33ms/step
# 95.40% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 46ms/step
# 98.97% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 97.37% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 99.54% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 98.56% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 99.08% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 45ms/step
# 97.05% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 99.21% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 99.23% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 86.33% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 93.89% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 65ms/step
# 98.50% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 49ms/step
# 95.36% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 58ms/step
# 99.97% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 68.79% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 96.28% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 85.76% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 61.31% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 89.42% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 88.20% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 98.80% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 98.59% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 99.60% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 98.30% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 99.26% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 96.58% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 97.82% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 94.82% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 99.76% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 84.94% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 98.09% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 99.69% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 96.51% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 91.97% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 99.88% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 97.34% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 94.79% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 98.76% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 82.43% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 98.61% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 81.61% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 93.28% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 98.33% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 76.31% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 99.88% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 67.40% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 97.25% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 59.32% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 53ms/step
# 95.59% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 99.25% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 98.35% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 98.30% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 72.09% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 94.90% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 79.56% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 93.75% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 69.37% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 33ms/step
# 82.69% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 58ms/step
# 99.86% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 97.94% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 98.32% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 79.56% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 98.38% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 99.39% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 78.45% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 33ms/step
# 62.62% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 32ms/step
# 98.12% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 33ms/step
# 96.46% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 52ms/step
# 94.58% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 97.45% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 91.77% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 93.43% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 95.19% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 94.23% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 98.67% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 31ms/step
# 89.97% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 58.43% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 92.45% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 32ms/step
# 99.45% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 99.67% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 97.88% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 97.91% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 99.16% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 91.49% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 50.09% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 83.07% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 89.96% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 98.30% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 98.30% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 95.60% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 52ms/step
# 98.76% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 99.41% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 33ms/step
# 99.51% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 99.51% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 74.65% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 99.10% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 96.27% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 59.32% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 75.40% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 99.82% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 80.72% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 99.62% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 96.91% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 33ms/step
# 96.52% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 102ms/step
# 99.75% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 99.08% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 82.20% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 32ms/step
# 73.48% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 78.13% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 99.04% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 79.59% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 92.48% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 83.63% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 99.58% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 95.63% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 55.25% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 99.72% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 98.95% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 97.27% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 98.34% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 96.85% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 88.30% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 98.02% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 45ms/step
# 92.36% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 46ms/step
# 99.35% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 98.43% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 81.15% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 46ms/step
# 99.34% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 46ms/step
# 97.80% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 85.63% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 97.48% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 56.94% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 87.46% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 74.18% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 98.64% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 99.36% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 45ms/step
# 98.68% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 99.72% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 92.03% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 51ms/step
# 96.76% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 66ms/step
# 92.31% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 99.86% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 81ms/step
# 98.62% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 79.75% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 50ms/step
# 98.13% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 54ms/step
# 76.27% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 55ms/step
# 79.71% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 54ms/step
# 72.15% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 98.78% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 58ms/step
# 94.06% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 51ms/step
# 92.13% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 67ms/step
# 87.11% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 60.78% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 45ms/step
# 56.01% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 98.47% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 74.10% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 94.77% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 75.30% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 91ms/step
# 97.02% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 96.28% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 57ms/step
# 77.47% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 72.97% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 98.30% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 79.56% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 99.36% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 98.17% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 99.05% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 99.09% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 50ms/step
# 71.00% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 99.08% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 97.75% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 99.72% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 95.84% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 99.64% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 99.90% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 90.46% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 98.73% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 45ms/step
# 73.78% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 99.09% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 93.83% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 51ms/step
# 84.83% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 63.40% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 58.60% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 93.25% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 60.84% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 84.73% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 96.50% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 99.09% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 75.45% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 59.63% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 87.13% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 47ms/step
# 97.47% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 54ms/step
# 98.62% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 99.39% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 96.62% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 99.18% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 52ms/step
# 92.44% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 53ms/step
# 99.99% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 99.41% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 89.83% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 33ms/step
# 98.91% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 98.28% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 79.13% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 99.09% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 95.72% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 98.26% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 50ms/step
# 92.24% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 56ms/step
# 66.59% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 109ms/step
# 98.91% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 47ms/step
# 93.88% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 59ms/step
# 91.21% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 49ms/step
# 71.88% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 75.10% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 98.33% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 88.28% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 87.11% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 98.48% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 97.17% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 98.70% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 89.56% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 97.85% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 67.52% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 52ms/step
# 73.58% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 96.58% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 46ms/step
# 99.59% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 70.70% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 87.18% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 72.69% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 97.97% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 99.63% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 97.77% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 99.93% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 60ms/step
# 85.65% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 52ms/step
# 93.92% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 97.41% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 99.94% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 78.60% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 51.63% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 84.12% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 57ms/step
# 99.19% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 81.43% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 47ms/step
# 63.09% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 66.05% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 82.95% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 59.30% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 73.41% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 99.22% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 73.45% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 95.80% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 97.82% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 45ms/step
# 99.04% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 58ms/step
# 68.54% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 95.88% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 98.21% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 87.37% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 51ms/step
# 98.46% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 94.01% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 98.76% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 99.63% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 78.02% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 45ms/step
# 62.93% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 99.59% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 87.03% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 99.57% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 49ms/step
# 97.37% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 92.35% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 51ms/step
# 88.53% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 49ms/step
# 99.35% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 99.83% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 99.39% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 71ms/step
# 75.19% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 94.27% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 51ms/step
# 77.35% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 49ms/step
# 59.33% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 50ms/step
# 73.68% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 94.62% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 60.07% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 98.58% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 58ms/step
# 66.23% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 53.11% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 93.75% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 98.41% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 96.50% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 99.16% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 175ms/step
# 92.65% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 52ms/step
# 97.37% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 58.50% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 84.86% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 99.77% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 99.57% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 92.32% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 47ms/step
# 90.20% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 50ms/step
# 57.24% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 49ms/step
# 96.21% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 53ms/step
# 99.54% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 98.19% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 56ms/step
# 83.27% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 55ms/step
# 86.99% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 125ms/step
# 75.18% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 53ms/step
# 98.47% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 46ms/step
# 80.70% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 76.22% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 45ms/step
# 67.70% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 89.20% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 99.06% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 52.11% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 59.05% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 47ms/step
# 95.63% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 98.80% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 51ms/step
# 65.10% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 47ms/step
# 96.55% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 68.71% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 97.53% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 66ms/step
# 56.46% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 49ms/step
# 98.63% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 92.25% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 65.42% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 54.25% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 53.67% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 99.22% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 92.81% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 45ms/step
# 79.92% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 90.82% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 72.94% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 85.66% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 74.10% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 95.57% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 95.56% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 99.34% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 96.64% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 58ms/step
# 57.93% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 46ms/step
# 98.96% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 77.95% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 99.44% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 45ms/step
# 74.10% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 75.26% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 57ms/step
# 95.51% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 90.16% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 63.45% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 64.43% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 47ms/step
# 97.70% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 85.21% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 45ms/step
# 99.14% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 98.67% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 76.36% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 58ms/step
# 94.40% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 93.76% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 63.60% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 72.40% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 47ms/step
# 80.15% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 47ms/step
# 97.46% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 82.65% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 57.57% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 51.91% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 55.99% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 72.09% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 96.75% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 97.91% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 70ms/step
# 86.31% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 98.72% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 95.83% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 71.21% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 47ms/step
# 98.91% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 84.05% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 61.60% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 91.19% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 99.74% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 61.54% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 51.45% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 77.37% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 91.92% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 50ms/step
# ...
# 64.10% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 95ms/step
# 97.11% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 79.56% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 68.78% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 56.41% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 98.78% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 72.10% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 92.83% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 99.37% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 92.45% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 140ms/step
# 99.39% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 32ms/step
# 98.13% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 98.59% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 99.95% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 60.13% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 64ms/step
# 72.08% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 82.44% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 98.78% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 99.07% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 47ms/step
# 89.46% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 51ms/step
# 99.42% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 59ms/step
# 86.61% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 75.79% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 47ms/step
# 99.04% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 99.12% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 57ms/step
# 75.28% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 97.52% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 87.15% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 86.28% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 93.95% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 103ms/step
# 98.12% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 99.26% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 54ms/step
# 99.38% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 99.69% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 72ms/step
# 70.12% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 47ms/step
# 99.68% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 52.10% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 95.90% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 79.47% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 86.77% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 125ms/step
# 96.94% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 97.09% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 68.61% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 93.83% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 99.56% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 97.38% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 32ms/step
# 81.85% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 58ms/step
# 93.13% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 91.95% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 97.43% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 130ms/step
# 95.51% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 80.61% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 68.63% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 52ms/step
# 99.77% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 70ms/step
# 65.30% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 96.04% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 92.45% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 63ms/step
# 98.92% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 69.61% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 96.93% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 77ms/step
# 91.82% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 63.45% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 98.86% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 57.08% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 85.65% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 33ms/step
# 90.20% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 82.73% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 95.04% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 67ms/step
# 85.64% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 26ms/step
# 67.10% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 134ms/step
# 79.65% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 47ms/step
# 98.36% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 60ms/step
# 92.29% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 65.52% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 59ms/step
# 68.72% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 47ms/step
# 96.85% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 46ms/step
# 94.64% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 54ms/step
# 58.89% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 61.85% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 99.77% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 112ms/step
# 97.19% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 50.29% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 62.95% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 95.38% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 57.32% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 91.15% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 96.22% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 84.95% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 71.06% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 94.80% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 56ms/step
# 73.75% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 87.51% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 57.66% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 95.90% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 75.50% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 54.96% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 99.84% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 55ms/step
# 55.17% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 91.62% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 98.24% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 128ms/step
# 81.73% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 60.58% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 96.76% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 84.02% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 90.44% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 97.96% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 98.38% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 95.26% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 98.93% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 98.68% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 176ms/step
# 98.54% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 62.72% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 98.65% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 46ms/step
# 79.58% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 53.20% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 66ms/step
# 89.61% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 98.68% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 90.04% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 51ms/step
# 56.79% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 99.94% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 150ms/step
# 83.51% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 29ms/step
# 95.45% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 99.88% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 98.99% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 54ms/step
# 99.48% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 96.17% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 54.97% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 45ms/step
# 96.79% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 99.29% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 99.96% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 52ms/step
# 89.67% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 87ms/step
# 97.62% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 98.91% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 73.17% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 82.61% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 67.95% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 94.11% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 71.98% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 97.31% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 130ms/step
# 99.08% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 84.83% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 99.27% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 97.57% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 99.52% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 93.88% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 46ms/step
# 95.40% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 93.62% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 65.01% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 99.35% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 193ms/step
# 86.87% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 98.86% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 46ms/step
# 90.25% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 65ms/step
# 97.94% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 73ms/step
# 99.15% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 99.03% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 99.45% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 78.80% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 98.50% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 77.49% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 84ms/step
# 92.38% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 92.31% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 99.75% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 51ms/step
# 95.85% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 97.64% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 85.20% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 97.31% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 99.09% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 80.70% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 48ms/step
# 94.04% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 149ms/step
# 98.52% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 68.43% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 96.40% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 99.47% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 93.59% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 76.81% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 46ms/step
# 88.32% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 82.03% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 84.20% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 44ms/step
# 98.66% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 129ms/step
# 99.96% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 98.69% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 53ms/step
# 99.95% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 46ms/step
# 98.62% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 95.95% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 87.47% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 33ms/step
# 66.32% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 94.99% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 35ms/step
# 99.16% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 56.75% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 79ms/step
# 98.62% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 53ms/step
# 99.88% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 60ms/step
# 65.11% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 65ms/step
# 98.86% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 46ms/step
# 96.62% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 93.30% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 38ms/step
# 83.99% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 93.89% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 99.69% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 90.80% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 116ms/step
# 92.66% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 71.17% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 97.51% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 97.95% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 36ms/step
# 88.90% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 97.84% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 40ms/step
# 99.50% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 39ms/step
# 98.30% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 34ms/step
# 68.10% 확률로 부정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 97.80% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 114ms/step
# 92.91% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 49ms/step
# 77.72% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 98.96% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 42ms/step
# 95.49% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 97.59% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 37ms/step
# 97.84% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 52ms/step
# 95.05% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 41ms/step
# 96.63% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 45ms/step
# 88.69% 확률로 긍정 리뷰입니다.
# 1/1 [==============================] - 0s 43ms/step
# 99.36% 확률로 긍정 리뷰입니다.

# %%
# 토크나이저의 단어 인덱스 확인
print(tokenizer.word_index)

# 모델의 임베딩 층의 가중치 가져오기
embedding_layer = loaded_model.layers[0]  # 임베딩 층의 인덱스는 모델의 첫 번째 층일 가능성이 높습니다.
embedding_weights = embedding_layer.get_weights()[0]

# 임베딩 가중치의 크기 출력
print(embedding_weights.shape)  # (vocab_size, embedding_dim)
# Out:
# {'OOV': 1, '멋지': 2, '고맙': 3, '재밌': 4, '알차': 5, '조': 6, '밝': 7, '푸하': 8, '슴슴하': 9, '실하': 10, '한결같': 11, '변함없': 12, '갈리': 13, '다시': 14, '반하': 15, '찐하': 16, '삐': 17, '메': 18, '머': 19, '끝내주': 20, '졸': 21, '가늘': 22, '형편없': 23, '녀': 24, '만지': 25, '까다롭': 26, '취하': 27, '답': 28, '흔하': 29, '개': 30, '잊': 31, '조르': 32, '파': 33, '더하': 34, '소문나': 35, '갔다오': 36, '귀엽': 37, '무섭': 38, '놀래': 39, '걸맞': 40, '날카롭': 41, '뛰어나': 42, '아름답': 43, '낯설': 44, '옳': 45, '꾀': 46, '띄': 47, '떠오르': 48, '알려주': 49, '갖추': 50, '보여주': 51, '나뉘': 52, '놀러오': 53, '잘생기': 54, '헤': 55, '잡치': 56, '절': 57, '풀리': 58, '엄': 59, '뽑': 60, '긋': 61, '어쩧': 62, '순하': 63, '붉': 64, '쌩까': 65, '갈하': 66, '내려가': 67, '쓰리': 68, '도와주': 69, '제공받': 70, '문제없': 71, '미루': 72, '드물': 73, '어처구니없': 74, '고프': 75, '진행하': 76, '잘': 77, '흥겹': 78, '별다르': 79, '어이없': 80, '괜챦': 81, '떨어트리': 82, '비우': 83, '살리': 84, '감': 85, '흘르': 86, '꼬': 87, '묵': 88, '붓': 89, '잊어버리': 90, '뵈': 91, '해먹': 92, '싸이': 93, '오지': 94, '끓': 95, '다지': 96, '깍': 97, '꺼지': 98, '접하': 99, '반기': 100, '헤매': 101, '지치': 102, '반갑': 103, '늘어나': 104, '굵': 105, '새': 106, '습하': 107, '사기치': 108, '이루': 109, '얹': 110, '내주': 111, '진정하': 112, '머물': 113, '어울어지': 114, '알쏭하': 115, '써먹': 116, '찿': 117, '높이': 118, '씻': 119, '글': 120, '후하': 121, '둥글': 122, '동그랗': 123, '흔들리': 124, '궁상맞': 125, '누': 126, '재미나': 127, '서툴': 128, '쓸': 129, '묘하': 130, '모': 131, '모자르': 132, '하고프': 133, '매우': 134, '놔두': 135, '못되': 136, '숨기': 137, '괴': 138, '삶': 139, '들어보': 140, '잡히': 141, '잦': 142, '돌아서': 143, '입히': 144, '나서': 145, '어설프': 146, '뒤지': 147, '더리': 148, '살피': 149, '용하': 150, '낚이': 151, '담그': 152, '화나': 153, '편찮': 154, '대이': 155, '마지못하': 156, '꼬지': 157, '눕': 158, '배이': 159, '서투르': 160, '이끌': 161, '남다르': 162, '앗': 163, '눈부시': 164, '게으르': 165, '잡스럽': 166, '파이': 167, '손쉽': 168, '배': 169, '햇갈리': 170, '차가워지': 171, '보기좋': 172, '움직이': 173, '펴': 174, '미끄럽': 175, '험하': 176, '읽': 177, '알맞': 178, '동하': 179, '갑작스럽': 180, '매': 181, '이러저러하': 182, '돋구': 183, '쌔': 184, '역하': 185, '시덥': 186, '적히': 187, '거칠': 188, '북적거리': 189, '손색없': 190, '지겹': 191, '드나들': 192, '시커멓': 193, '토하': 194, '찍히': 195, '애먹': 196, '기똥차': 197, '뜸하': 198, '누렇': 199, '어딨': 200, '뜻깊': 201, '태리': 202, '기쁘': 203, '고되': 204, '째': 205, '떠다니': 206, '새초롬하': 207, '올려놓': 208, '끝장나': 209, '설레': 210, '사귀': 211, '노랗': 212, '건지': 213, '달디달': 214, '꺼주': 215, '푸지': 216, '오목하': 217, '인상깊': 218, '혼나': 219, '뺏': 220, '못생기': 221, '숭하': 222, '꼽': 223, '불만족스럽': 224, '놓이': 225, '둏': 226, '사납': 227, '재확인하': 228, '특출나': 229, '번거럽': 230, '부적절하': 231, '뒤늦': 232, '앙증맞': 233, '꾸미': 234, '웃기': 235, '솔': 236, '잽싸': 237, '비슷하': 238, '떫': 239, '재': 240, '넒': 241, '낄': 242, '따갑': 243, '수근거리': 244, '오래': 245, '에돌': 246, '까딱하': 247, '처넣': 248, '기하': 249, '들키': 250, '쫓기': 251, '줄서': 252, '무치': 253, '쌓이': 254, '헤치': 255, '사랑받': 256, '깨닫': 257, '끼우': 258, '불리': 259, '내비치': 260, '꼬이': 261, '졀': 262, '잠들': 263, '늠': 264, '끌': 265, '솟': 266, '젓': 267, '집어내': 268, '끝': 269, '힘내': 270, '굴러떨어지': 271, '잡아두': 272, '늦어지': 273, '접': 274, '알아듣': 275, '치루': 276, '다다르': 277, '조이': 278, '깊이': 279, '찌뿌리': 280, '투덜대': 281, '노이': 282, '서둘': 283, '쨍하': 284, '그리워지': 285, '떼이': 286, '쭐': 287, '가라앉': 288, '건너': 289, '알아주': 290, '날르': 291, '요하': 292, '받아먹': 293, '앓아눕': 294, '돌려보내': 295, '기어다니': 296, '화내': 297, '틀리': 298, '멈추': 299, '올려보': 300, '우려내': 301, '넓히': 302, '새우': 303, '끝내': 304, '명하': 305, '자시': 306, '맞아떨어지': 307, '녹아내리': 308, '돌아가시': 309, '담구': 310, '냅두': 311, '켜지': 312, '떠나': 313, '으스러지': 314, '채워놓': 315, '긁': 316, '흩': 317, '내노': 318, '내두르': 319, '먹이': 320, '말라붙': 321, '싸우': 322, '넘어서': 323, '눈치채': 324, '지리': 325, '받아치': 326, '때려치': 327, '따내': 328, '가만있': 329, '지시': 330, '재끼': 331, '주무시': 332, '삼': 333, '거르': 334, '사리': 335, '정떨어지': 336, '으깨': 337, '불러일으키': 338, '감치': 339, '부라리': 340, '저쩌': 341, '궁시렁대': 342, '날라다니': 343, '맥히': 344, '날아다니': 345, '곧': 346, '예이': 347, '엎지르': 348, '당그': 349, '외치': 350, '히': 351, '펼쳐지': 352, '속': 353, '섬하': 354, '터트리': 355, '식히': 356, '등지': 357, '터뜨리': 358, '주고받': 359, '저버리': 360, '삐지': 361, '잘못하': 362, '퍼가': 363, '끼리': 364, '빼먹': 365, '드러나': 3 ...
# (532, 100)

# %%
data.to_csv('./data/data_vv.csv', encoding='utf-8-sig')

# %%
data.loc[data['label'] == -1, 'label'] = 0

# %%
data
# Out:
#        Unnamed: 0                 review_id  \
# 0              33  60d00802ddab3800506106eb
# 1              34  60b63d1a74dab90050fa6896
# 2              35  60b434324caa1a005051f04e
# 3              36  607edb15268a2a004fd62779
# 4              37  6061b37ac701b50075941464
# ...           ...                       ...
# 11697       30007  5d0b71e5484d1eee9d932761
# 11698       30008  5ca6ef601b2052a5d8f567cd
# 11699       30009  5c977ab3a676ed62866c886f
# 11700       30010  5c7fb58af6aecd8a0acd4eb8
# 11701       30011  5c764732a021efcc81e17023
#
#                                                     body    visited  \
# 0      손님 놓치기 싫어서 지하층으로 손님을 받을거면 동일한 서비스를 제공하세요  그동안 ...  21.6.21.월
# 1                                           김치찌개랑 계란말이 쨩  21.5.28.금
# 2                                            파절이가 좀 아쉽네요  21.5.26.수
# 3                                                   맛있어요  21.4.13.화
# 4                                                    바빠요  21.3.29.월
# ...                                                  ...        ...
# 11697                                        케익이 맛있는 아티제  19.6.20.목
# 11698  삼성타운에 맛집이 참 많네요 그래도 커피 케익은 아티재 인가봅니다 페이코 할인되는 ...   19.4.5.금
# 11699                                              주차가돼요  19.3.24.일
# 11700                    깔끔하고 저녁엔 회사 사람들이 빠져나가서 조용하고 좋네요   19.3.6.수
# 11701                                       삼성타워 크고 좋음 ㅎ  19.2.27.수
#
#        viewCount  restaurant_id businessName  rating  \
# 0            494       11487063     구이마마 대치점     0.5
# 1            453       11487063     구이마마 대치점     5.0
# 2            384       11487063     구이마마 대치점     3.5
# 3            311       11487063     구이마마 대치점     5.0
# 4            300       11487063     구이마마 대치점     4.0
# ...          ...            ...          ...     ...
# 11697         10       13066017    아티제 삼성타운점     4.0
# 11698         16       13066017    아티제 삼성타운점     3.0
# 11699         88       13066017    아티제 삼성타운점     5.0
# 11700         10       13066017    아티제 삼성타운점     4.0
# 11701         10       13066017    아티제 삼성타운점     4.0
#
#                                                    nouns  \
# 0      ['손님', '지하층', '손님', '거', '동일', '서비스', '제공', '앞...
# 1                                    ['김치찌개', '계란', '말']
# 2                                                 ['파절']
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 11697                                        ['케익', '티']
# 11698  ['삼성', '타운', '맛', '집', '커피', '케익', '코', '할인', ...
# 11699                                             ['주차']
# 11700                                 ['저녁', '회사', '사람']
# 11701                                  ['삼성', '타워', 'ㅎ']
#
#                                                    verbs  adjectives  \
# 0      ['놓치', '싫', '받', '이', '가', '갈', '이', '하', '달라'...  ['싫', '없']
# 1                                                     []          []
# 2                                            ['가', '아쉽']      ['아쉽']
# 3                                                 ['맛있']      ['맛있']
# 4                                                 ['바쁘']      ['바쁘']
# ...                                                  ...         ...
# 11697                                        ['맛있', '아']      ['맛있']
# 11698                        ['많', '그리하', '이', '보', '꾸']       ['많']
# 11699                                              ['되']          []
# 11700                                      ['빠져나가', '좋']       ['좋']
# 11701                                         ['크', '좋']  ['크', '좋']
#
#                                             exclamations  label  \
# 0      ['기', '어서', '을', '면', 'ㄴ', '세요', '었', '지만', 'ㅂ...      0
# 1                                                     []      1
# 2                                            ['아', '네요']      1
# 3                                                 ['어요']      1
# 4                                                 ['아요']      1
# ...                                                  ...    ...
# 11697                                         ['는', '아']      1
# 11698                ['네요', '여도', 'ㄴ가', 'ㅂ니다', '는', 'ㄹ']      0
# 11699                                             ['어요']      1
# 11700                              ['고', '서', '고', '네요']      1
# 11701                                         ['고', '음']      1
#
#                                                tokenized new_label  \
# 0      ['놓치', '싫', '받', '이', '가', '갈', '이', '하', '달라'...         1
# 1                                                     []         0
# 2                                      ['가', '아쉽', '아쉽']         0
# 3                                           ['맛있', '맛있']         0
# 4                                           ['바쁘', '바쁘']         0
# ...                                                  ...       ...
# 11697                                  ['맛있', '아', '맛있']         0
# 11698                   ['많', '그리하', '이', '보', '꾸', '많']         0
# 11699                                              ['되']         0
# 11700                                 ['빠져나가', '좋', '좋']         0
# 11701                               ['크', '좋', '크', '좋']         0
#
#       tokenized_comment                    tokenized_comments
# 0                  None  [놓치, 싫, 받, 없, 눈치보, 되, 깎, 받, 하, 수근거리]
# 1                  None                                    []
# 2                  None                                  [아쉽]
# 3                  None                                  [맛있]
# 4                  None                                    []
# ...                 ...                                   ...
# 11697              None                                  [맛있]
# 11698              None                                   [많]
# 11699              None                                    []
# 11700              None                             [빠져나가, 좋]
# 11701              None                                [크, 좋]
#
# [11702 rows x 17 columns]

# %%
data['Rating'].dtype
# Out:
# dtype('int64')

# %%
data['new_label'] = data['new_label'].astype('int32')

# %%
data['new_label'].dtype
# Out:
# dtype('int32')

# %%
same_count = (data['Rating'] == data['new_label']).sum()
different_count = len(data) - same_count

# 결과 출력
print(f"같은 것의 개수: {same_count}")
print(f"다른 것의 개수: {different_count}")
# Out:
# 같은 것의 개수: 9277
# 다른 것의 개수: 1209

# %%
# TN, TP, FN, FP 계산
TN = ((data['Rating'] == 0) & (data['new_label'] == 0)).sum()
TP = ((data['Rating'] == 1) & (data['new_label'] == 1)).sum()
FN = ((data['Rating'] == 1) & (data['new_label'] == 0)).sum()
FP = ((data['Rating'] == 0) & (data['new_label'] == 1)).sum()

# 결과 출력
print(f"TN: {TN}")
print(f"TP: {TP}")
print(f"FN: {FN}")
print(f"FP: {FP}")
# Out:
# TN: 427
# TP: 8850
# FN: 1118
# FP: 91

# %%
# 전체 샘플 수
total_samples = len(data)

# 정확하게 예측된 샘플 수
correct_predictions = TP + TN

# 정확도 계산
accuracy = correct_predictions / total_samples

# 결과 출력
print(f"정확도: {accuracy}")
# Out:
# 정확도: 0.8847034140759107

# %%
data.to_csv("data.csv", encoding='utf-8-sig')

# %%
test_data.dropna(subset="rating")
# Out:
#                       review_id  \
# 33     60d00802ddab3800506106eb
# 34     60b63d1a74dab90050fa6896
# 35     60b434324caa1a005051f04e
# 36     607edb15268a2a004fd62779
# 37     6061b37ac701b50075941464
# ...                         ...
# 30007  5d0b71e5484d1eee9d932761
# 30008  5ca6ef601b2052a5d8f567cd
# 30009  5c977ab3a676ed62866c886f
# 30010  5c7fb58af6aecd8a0acd4eb8
# 30011  5c764732a021efcc81e17023
#
#                                                     body    visited  \
# 33     손님 놓치기 싫어서 지하층으로 손님을 받을거면 동일한 서비스를 제공하세요  그동안 ...  21.6.21.월
# 34                                          김치찌개랑 계란말이 쨩  21.5.28.금
# 35                                           파절이가 좀 아쉽네요  21.5.26.수
# 36                                                  맛있어요  21.4.13.화
# 37                                                   바빠요  21.3.29.월
# ...                                                  ...        ...
# 30007                                        케익이 맛있는 아티제  19.6.20.목
# 30008  삼성타운에 맛집이 참 많네요 그래도 커피 케익은 아티재 인가봅니다 페이코 할인되는 ...   19.4.5.금
# 30009                                              주차가돼요  19.3.24.일
# 30010                    깔끔하고 저녁엔 회사 사람들이 빠져나가서 조용하고 좋네요   19.3.6.수
# 30011                                       삼성타워 크고 좋음 ㅎ  19.2.27.수
#
#        viewCount  restaurant_id businessName  rating  \
# 33           494       11487063     구이마마 대치점     0.5
# 34           453       11487063     구이마마 대치점     5.0
# 35           384       11487063     구이마마 대치점     3.5
# 36           311       11487063     구이마마 대치점     5.0
# 37           300       11487063     구이마마 대치점     4.0
# ...          ...            ...          ...     ...
# 30007         10       13066017    아티제 삼성타운점     4.0
# 30008         16       13066017    아티제 삼성타운점     3.0
# 30009         88       13066017    아티제 삼성타운점     5.0
# 30010         10       13066017    아티제 삼성타운점     4.0
# 30011         10       13066017    아티제 삼성타운점     4.0
#
#                                                tokenized label new_label  \
# 33     ['손님', '놓치', '기', '싫', '어서', '지하층', '으로', '손님'...    부정         0
# 34                         ['김치찌개', '랑', '계란', '말', '쨩']    긍정         1
# 35                          ['파절', '아', '좀', '아쉽', '네요']    긍정         0
# 36                                          ['맛있', '어요']    긍정         0
# 37                                          ['바쁘', '아요']    긍정         0
# ...                                                  ...   ...       ...
# 30007                   ['케익', '맛있', '아', '아', '티', '제']    긍정         0
# 30008  ['삼성', '타운', '맛', '집', '참', '많', '네요', '그리하', ...    부정         0
# 30009                                  ['주차', '되', '어요']    긍정         0
# 30010  ['깔끔', '저녁', '회사', '사람', '빠져나가', '서', '조용', '좋...    긍정         0
# 30011                   ['삼성', '타워', '크', '좋', '음', 'ㅎ']    긍정         0
#
#       tokenized_comment                                 tokenized_comments
# 33                 None  [손, 지하, 층, 손님, 거, 서비스, 제공, 동안, 앞, 번, 사장, 남자, 분...
# 34                 None                                      [김치찌개, 계란, 말]
# 35                 None                                            [파절, 이]
# 36                 None                                                 []
# 37                 None                                                 []
# ...                 ...                                                ...
# 30007              None                                            [케익, 티]
# 30008              None            [삼성타운, 맛집, 커피, 케익, 아티, 페이, 코, 할인, 건, 팁]
# 30009              None                                               [주차]
# 30010              None                                       [저녁, 회사, 사람]
# 30011              None                                           [삼성, 타워]
#
# [11702 rows x 12 columns]

# %%
test_data.loc[data['label'] == '긍정', 'label'] = 1
test_data.loc[data['label'] == '부정', 'label'] = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 test_data.loc[data['label'] == '긍정', 'label'] = 1
#       2 test_data.loc[data['label'] == '부정', 'label'] = 0
#
# NameError: name 'test_data' is not defined
