# %%
# !pip install transformers

# %%
# !pip install datasets

# %%
# !pip install torch

# %%
# !pip install torchvision

# %%
from transformers import SwinConfig, AutoImageProcessor, SwinForImageClassification, Trainer
from datasets import load_dataset, load_metric

import torch
import torchvision
import numpy as np

# %%
dataset = load_dataset("cats_vs_dogs")
print('기존 :', dataset)
# Out:
# Generating train split:   0%|          | 0/23410 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\Playdata\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\builder.py:1743, in GeneratorBasedBuilder._prepare_split_single(self, gen_kwargs, fpath, file_format, max_shard_size, split_info, check_duplicate_keys, job_id)
#    1734     writer = writer_class(
#    1735         features=writer._features,
#    1736         path=fpath.replace("SSSSS", f"{shard_id:05d}").replace("JJJJJ", f"{job_id:05d}"),
#    (...)
#    1741         embed_local_files=embed_local_files,
#    1742     )
# -> 1743 example = self.info.features.encode_example(record) if self.info.features is not None else record
#    1744 writer.write(example, key)
#
# ...

# %%
# dataset의 features의 'image', 'labels' 를 통일시켜주는 게 편하다
# 데이터셋마다 'img', 'image', 'images' 등 다양하게 표기되어 있음

dataset = load_dataset("cats_vs_dogs")
print('기존 :', dataset)

dataset['train'] = dataset['train'].rename_column("labels", "label")

# Pytorch 데이터셋 포맷 세팅
dataset.set_format("torch")

print('변경 후 :',dataset)
# Out:
# c:\Users\Playdata\AppData\Local\Programs\Python\Python311\Lib\site-packages\datasets\load.py:1454: FutureWarning: The repository for cats_vs_dogs contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/cats_vs_dogs
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# ...
# Generating train split:   0%|          | 0/23410 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ...
